# %%
import numpy as np
import matplotlib.pyplot as plt

N = 50
D = 50

# uniformly distributed numbers between -5, +5
X = (np.random.random((N, D)) - 0.5)*10

# true weights - only the first 3 dimensions of X affect Y
true_w = np.array([1, 0.5, -0.5] + [0]*(D - 3))

# generate Y - add noise
Y = X.dot(true_w) + np.random.randn(N)*0.5

# perform gradient descent to find w
costs = [] # keep track of squared error cost
w = np.random.randn(D) / np.sqrt(D) # randomly initialize w
learning_rate = 0.001
l1 = 10.0 # Also try 5.0, 2.0, 1.0, 0.1 - what effect does it have on w?
for t in range(500):
    # update w
    Yhat = X.dot(w)
    delta = Yhat - Y
    w = w - learning_rate*(X.T.dot(delta) + l1*np.sign(w))

    # find and store the cost
    mse = delta.dot(delta) / N
    costs.append(mse)

# plot the costs
plt.plot(costs)
plt.show()

print("final w:", w)

# plot our w vs true w
plt.plot(true_w, label='true w')
plt.plot(w, label='w_map')
plt.legend()
plt.show()
# Out:
# final w: [ 9.59176988e-01  4.79323314e-01 -4.73892886e-01  8.84414198e-03
#  -9.65523986e-03  4.69718629e-02 -5.13817518e-03  1.04869015e-02
#   2.76321550e-03 -4.93762760e-03  3.37958885e-02 -1.12103636e-02
#   1.20367856e-03  2.39975770e-04  2.08363089e-03 -3.64762544e-02
#  -6.74811913e-03 -2.66942614e-03 -8.98188270e-04  3.53987516e-02
#  -1.31317371e-03 -2.32030225e-02  2.18599964e-02 -2.15626967e-02
#  -1.40668382e-02  1.21390970e-02  2.48594535e-03 -2.18049477e-02
#   2.94442754e-02 -1.77183075e-02 -1.16525831e-02  5.85370491e-04
#   1.01825027e-03  1.38159911e-02  2.83631374e-02 -2.25558617e-02
#  -4.98483716e-03  1.60275012e-02  6.37060139e-03 -2.56795171e-02
#  -1.06451559e-02 -1.46650770e-02 -2.54122238e-02  1.21412364e-02
#   6.61851406e-03 -1.50242914e-02  6.19344093e-03  6.52028154e-03
#  -2.61936151e-02 -2.24641744e-02]

# %%
X = (np.random.random((N, D)))

# %%
X.shape
# Out:
# (50, 50)
